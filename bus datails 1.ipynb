# %%
import time
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import WebDriverWait
from selenium.common.exceptions import TimeoutException, NoSuchElementException
from selenium.webdriver.support import expected_conditions as EC
import pandas as pd

# %% [markdown]
# kerala bus details

# %%
#read the csv file
df=pd.read_csv("C:/Users/HP/Desktop/csv files/df_k.csv")
df
# Out:
#                         route_name  \
# 0           Bangalore to Kozhikode
# 1           Kozhikode to Bangalore
# 2           Kozhikode to Ernakulam
# 3           Ernakulam to Kozhikode
# 4              Bangalore to Kannur
# 5              Kozhikode to Mysore
# 6              Kannur to Bangalore
# 7  Kozhikode to Thiruvananthapuram
# 8              Mysore to Kozhikode
# 9   Bangalore to Kalpetta (kerala)
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/bangalore-to...
# 1  https://www.redbus.in/bus-tickets/kozhikode-to...
# 2  https://www.redbus.in/bus-tickets/kozhikode-to...
# 3  https://www.redbus.in/bus-tickets/ernakulam-to...
# 4  https://www.redbus.in/bus-tickets/bangalore-to...
# 5  https://www.redbus.in/bus-tickets/kozhikode-to...
# 6  https://www.redbus.in/bus-tickets/kannur-to-ba...
# 7  https://www.redbus.in/bus-tickets/kozhikode-to...
# 8  https://www.redbus.in/bus-tickets/mysore-to-ko...
# ...

# %%
#retreive the data
driver_k=webdriver.Chrome()
Bus_names_k=[]
Bus_types_k=[]
Start_Time_k=[]
End_Time_k=[]
Ratings_k=[]
Total_Duration_k=[]
Prices_k=[]
Seats_Available_k=[]
Route_names=[]
Route_links=[]

for i,r in df.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_k.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_k.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_k.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_k.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_k).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_k.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_k.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_k.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_k.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_k.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_k.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_k.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_k.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_k.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")

  for name in bus_names:
    Bus_names_k.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_k.append(bus_type.text)
  for start in start_time:
    Start_Time_k.append(start.text)
  for end in end_time:
    End_Time_k.append(end.text)
  for total in total_duration:
    Total_Duration_k.append(total.text)
  for rate in ratings:
    Ratings_k.append(rate.text)
  for pri in price:
    Prices_k.append(pri.text)
  for seats in seats_available:
    Seats_Available_k.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_k={'Bus_names':Bus_names_k,
        'Bus_types':Bus_types_k,
        'Start_Time':Start_Time_k,
        'End_Time':End_Time_k,
        'Ratings':Ratings_k,
        'Total_Duration':Total_Duration_k,
        'Prices':Prices_k,
        'Seats_Available':Seats_Available_k,
        'Route_names':Route_names,
        'Route_link':Route_links
        }
df_buses_1=pd.DataFrame(data_k)
#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_1.csv"
df_buses_1.to_csv(path,index=False)

# %%
df_buses_1
# Out:
#                          Bus_names                                  Bus_types  \
# 0     CHANCHALAS TOURS AND TRAVELS                     A/C Semi Sleeper (2+2)
# 1                      MMK Travels                 A/C Seater / Sleeper (2+1)
# 2                      P K Travels                 A/C Seater / Sleeper (2+1)
# 3              SKS Tours & Travels
# 4
# 5             KSRTC (Kerala) - 503  Super Express Non AC Seater Air Bus (2+2)
# 6            KSRTC (Kerala) - 2900                    Low Floor AC Seater 2+2
# 7             KSRTC (Kerala) - 564  Super Express Non AC Seater Air Bus (2+2)
# 8
# 9
# 10
# 11
# 12
# 13
# 14
# 15           KSRTC (Kerala) - 2569             Super Fast Non AC Seater (2+3)
# 16            KSRTC (Kerala) - 549  Super Express Non AC Seater Air Bus (2+2)
# 17           KSRTC (Kerala) - 2922             Super Fast Non AC Seater (2+3)
# 18           KSRTC (Kerala) - 3004             Super Fast Non AC Seater (2+3)
# 19
# 20
# 21
# 22
# 23
# 24
# ...

# %% [markdown]
# andrapradesh

# %%
df_A=pd.read_csv("C:/Users/HP/Desktop/csv files/df_A.csv")
df_A
# Out:
#                                route_name  \
# 0                 Hyderabad to Vijayawada
# 1                 Vijayawada to Hyderabad
# 2                     Hyderabad to Ongole
# 3               Kakinada to Visakhapatnam
# 4                   Bangalore to Tirupati
# 5                     Bangalore to Kadapa
# 6                     Ongole to Hyderabad
# 7                     Kadapa to Bangalore
# 8  Chittoor (Andhra Pradesh) to Bangalore
# 9               Visakhapatnam to Kakinada
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/hyderabad-to...
# 1  https://www.redbus.in/bus-tickets/vijayawada-t...
# 2  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3  https://www.redbus.in/bus-tickets/kakinada-to-...
# 4  https://www.redbus.in/bus-tickets/bangalore-to...
# 5  https://www.redbus.in/bus-tickets/bangalore-to...
# 6  https://www.redbus.in/bus-tickets/ongole-to-hy...
# 7  https://www.redbus.in/bus-tickets/kadapa-to-ba...
# ...

# %%
#retreive the data
driver_A=webdriver.Chrome()
Bus_names_A=[]
Bus_types_A=[]
Start_Time_A=[]
End_Time_A=[]
Ratings_A=[]
Total_Duration_A=[]
Prices_A=[]
Seats_Available_A=[]
Route_names=[]
Route_links=[]

for i,r in df_A.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_A.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_A.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_A.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_A.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_A).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_A.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_A.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_A.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_A.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_A.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_A.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_A.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_A.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_A.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")

  for name in bus_names:
    Bus_names_A.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_A.append(bus_type.text)
  for start in start_time:
    Start_Time_A.append(start.text)
  for end in end_time:
    End_Time_A.append(end.text)
  for total in total_duration:
    Total_Duration_A.append(total.text)
  for rate in ratings:
    Ratings_A.append(rate.text)
  for pri in price:
    Prices_A.append(pri.text)
  for seats in seats_available:
    Seats_Available_A.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_A={"Bus_names":Bus_names_A,
        "Bus_types":Bus_types_A,
        "Start_Time":Start_Time_A,
        "End_Time":End_Time_A,
        "Ratings":Ratings_A,
        "Total_Duration":Total_Duration_A,
        "Prices":Prices_A,
        "Seats_Available":Seats_Available_A,
        "Route_names":Route_names,
        "Route_link":Route_links
        }
df_buses_2=pd.DataFrame(data_A)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_2.csv"
df_buses_2.to_csv(path,index=False)

# %%
df_buses_2
# Out:
#          Bus_names                               Bus_types Start_Time  \
# 0    APSRTC - 5151          STAR LINER(NON-AC SLEEPER 2+1)      18:00
# 1    APSRTC - 5870  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      18:30
# 2    APSRTC - 5070  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      18:45
# 3   APSRTC - 48821  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      19:00
# 4    APSRTC - 5859  SUPER LUXURY (NON-AC, 2 + 2 PUSH BACK)      19:00
# ..             ...                                     ...        ...
# 71
# 72
# 73
# 74
# 75
#
#    End_Time  Ratings Total_Duration   Prices     Seats_Available  \
# 0     03:15  4.2\n25        09h 15m  INR 677  18 Seats available
# 1     04:00  3.6\n32        09h 30m  INR 522  17 Seats available
# 2     03:15   3.5\n5        08h 30m  INR 524  23 Seats available
# 3     04:15  4.2\n31        09h 15m  INR 522  23 Seats available
# 4     04:00  3.3\n16        09h 00m  INR 555  21 Seats available
# ...

# %% [markdown]
# HARYANA

# %%
df_H=pd.read_csv("C:/Users/HP/Desktop/csv files/df_H.csv")
df_H
# Out:
#                                      route_name  \
# 0                               Delhi to Shimla
# 1     Chandigarh to Hamirpur (Himachal Pradesh)
# 2     Hamirpur (Himachal Pradesh) to Chandigarh
# 3                               Shimla to Delhi
# 4                           Delhi to Chandigarh
# 5          Hamirpur (Himachal Pradesh) to Delhi
# 6       Chamba (Himachal Pradesh) to Chandigarh
# 7          Delhi to Hamirpur (Himachal Pradesh)
# 8  Chandigarh to Dharamshala (Himachal Pradesh)
# 9            Delhi to Chamba (Himachal Pradesh)
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/delhi-to-shimla
# 1  https://www.redbus.in/bus-tickets/chandigarh-t...
# 2  https://www.redbus.in/bus-tickets/hamirpur-him...
# 3  https://www.redbus.in/bus-tickets/shimla-to-delhi
# 4  https://www.redbus.in/bus-tickets/delhi-to-cha...
# 5  https://www.redbus.in/bus-tickets/hamirpur-him...
# 6  https://www.redbus.in/bus-tickets/chamba-himac...
# ...

# %%
#retreive the data
driver_H=webdriver.Chrome()
Bus_names_H=[]
Bus_types_H=[]
Start_Time_H=[]
End_Time_H=[]
Ratings_H=[]
Total_Duration_H=[]
Prices_H=[]
Seats_Available_H=[]
Route_names=[]
Route_links=[]

for i,r in df_H.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_H.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_H.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_H.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_H.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_H).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_H.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_H.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_H.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_H.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_H.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_H.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_H.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_H.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_H.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_H.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_H.append(bus_type.text)
  for start in start_time:
    Start_Time_H.append(start.text)
  for end in end_time:
    End_Time_H.append(end.text)
  for total in total_duration:
    Total_Duration_H.append(total.text)
  for rate in ratings:
    Ratings_H.append(rate.text)
  for pri in price:
    Prices_H.append(pri.text)
  for seats in seats_available:
    Seats_Available_H.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_H={"Bus_names":Bus_names_H,
        "Bus_types":Bus_types_H,
        "Start_Time":Start_Time_H,
        "End_Time":End_Time_H,
        "Ratings":Ratings_H,
        "Total_Duration":Total_Duration_H,
        "Prices":Prices_H,
        "Seats_Available":Seats_Available_H,
        "Route_names":Route_names,
        "Route_link":Route_links
        }
df_buses_3=pd.DataFrame(data_H)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_3.csv"
df_buses_3.to_csv(path,index=False)

# %%
df_buses_3
# Out:
#              Bus_names                           Bus_types Start_Time  \
# 0           HRTC - 656          Ordinary 3+2 Non AC Seater      15:10
# 1           HRTC - 620          Ordinary 3+2 Non AC Seater      15:10
# 2           HRTC - 603          Ordinary 3+2 Non AC Seater      16:40
# 3        HRTC - 401270          Ordinary 3+2 Non AC Seater      17:05
# 4           HRTC - 621          Ordinary 3+2 Non AC Seater      17:10
# 5       Laxmi holidays        Volvo A/C Semi Sleeper (2+2)      20:20
# 6   Ram Dalal Holidays        Volvo A/C Semi Sleeper (2+2)      21:15
# 7   Ram Dalal Holidays        Volvo A/C Semi Sleeper (2+2)      22:00
# 8            HRTC - 24  Himsuta AC Seater Volvo/Scania 2+2      13:45
# 9           HRTC - 103          Ordinary 3+2 Non AC Seater      17:18
# 10          HRTC - 181          Ordinary 3+2 Non AC Seater      17:50
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18         HRTC - 1532          Ordinary 3+2 Non AC Seater      14:00
# ...

# %% [markdown]
# KADAMBA TRANSPORT

# %%
df_KD=pd.read_csv("C:/Users/HP/Desktop/csv files/df_KD.csv")
df_KD
# Out:
#                        route_name  \
# 0                     Pune to Goa
# 1                     Goa to Pune
# 2                   Mumbai to Goa
# 3                Bangalore to Goa
# 4                Goa to Bangalore
# 5                   Goa to Mumbai
# 6               Pandharpur to Goa
# 7               Goa to Pandharpur
# 8                  Solapur to Goa
# 9  Calangute (goa) to Goa Airport
#
#                                           route_link
# 0      https://www.redbus.in/bus-tickets/pune-to-goa
# 1      https://www.redbus.in/bus-tickets/goa-to-pune
# 2    https://www.redbus.in/bus-tickets/mumbai-to-goa
# 3  https://www.redbus.in/bus-tickets/bangalore-to...
# 4  https://www.redbus.in/bus-tickets/goa-to-banga...
# 5    https://www.redbus.in/bus-tickets/goa-to-mumbai
# 6  https://www.redbus.in/bus-tickets/pandharpur-t...
# 7  https://www.redbus.in/bus-tickets/goa-to-pandh...
# 8   https://www.redbus.in/bus-tickets/solapur-to-goa
# ...

# %%
#retreive the data
driver_KD=webdriver.Chrome()
Bus_names_KD=[]
Bus_types_KD=[]
Start_Time_KD=[]
End_Time_KD=[]
Ratings_KD=[]
Total_Duration_KD=[]
Prices_KD=[]
Seats_Available_KD=[]
Route_names=[]
Route_links=[]

for i,r in df_KD.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_KD.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_KD.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_KD.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_KD.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_KD).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_KD.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_KD.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_KD.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_KD.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_KD.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_KD.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_KD.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_KD.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_KD.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_KD.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_KD.append(bus_type.text)
  for start in start_time:
    Start_Time_KD.append(start.text)
  for end in end_time:
    End_Time_KD.append(end.text)
  for total in total_duration:
    Total_Duration_KD.append(total.text)
  for rate in ratings:
    Ratings_KD.append(rate.text)
  for pri in price:
    Prices_KD.append(pri.text)
  for seats in seats_available:
    Seats_Available_KD.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_KD={"Bus_names":Bus_names_KD,
        "Bus_types":Bus_types_KD,
        "Start_Time":Start_Time_KD,
        "End_Time":End_Time_KD,
        "Ratings":Ratings_KD,
        "Total_Duration":Total_Duration_KD,
        "Prices":Prices_KD,
        "Seats_Available":Seats_Available_KD,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_4=pd.DataFrame(data_KD)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_4.csv"
df_buses_4.to_csv(path,index=False)

# %%
df_buses_4
# Out:
# Empty DataFrame
# Columns: [Bus_names, Bus_types, Start_Time, End_Time, Ratings, Total_Duration, Prices, Seats_Available, Route_names, Route_link]
# Index: []

# %% [markdown]
# ASSAM

# %%
df_AS=pd.read_csv("C:/Users/HP/Desktop/csv files/df_AS.csv")
df_AS
# Out:
#                     route_name  \
# 0           Tezpur to Guwahati
# 1           Guwahati to Tezpur
# 2   Guwahati to Nagaon (Assam)
# 3   Nagaon (Assam) to Guwahati
# 4         Goalpara to Guwahati
# 5    Jorhat to North Lakhimpur
# 6           Dhubri to Guwahati
# 7          Jorhat to Dibrugarh
# 8    North Lakhimpur to Jorhat
# 9  North Lakhimpur to Sibsagar
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/tezpur-to-gu...
# 1  https://www.redbus.in/bus-tickets/guwahati-to-...
# 2  https://www.redbus.in/bus-tickets/guwahati-to-...
# 3  https://www.redbus.in/bus-tickets/nagaon-to-gu...
# 4  https://www.redbus.in/bus-tickets/goalpara-to-...
# 5  https://www.redbus.in/bus-tickets/jorhat-to-no...
# 6  https://www.redbus.in/bus-tickets/dhubri-to-gu...
# 7  https://www.redbus.in/bus-tickets/jorhat-to-di...
# 8  https://www.redbus.in/bus-tickets/north-lakhim...
# 9  https://www.redbus.in/bus-tickets/north-lakhim...

# %%
#retreive the data
driver_AS=webdriver.Chrome()
Bus_names_AS=[]
Bus_types_AS=[]
Start_Time_AS=[]
End_Time_AS=[]
Ratings_AS=[]
Total_Duration_AS=[]
Prices_AS=[]
Seats_Available_AS=[]
Route_names=[]
Route_links=[]

for i,r in df_AS.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_AS.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_AS.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_AS.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_AS.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_AS).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_AS.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_AS.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_AS.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_AS.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_AS.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_AS.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_AS.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_AS.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_AS.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_AS.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_AS.append(bus_type.text)
  for start in start_time:
    Start_Time_AS.append(start.text)
  for end in end_time:
    End_Time_AS.append(end.text)
  for total in total_duration:
    Total_Duration_AS.append(total.text)
  for rate in ratings:
    Ratings_AS.append(rate.text)
  for pri in price:
    Prices_AS.append(pri.text)
  for seats in seats_available:
    Seats_Available_AS.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_AS={"Bus_names":Bus_names_AS,
        "Bus_types":Bus_types_AS,
        "Start_Time":Start_Time_AS,
        "End_Time":End_Time_AS,
        "Ratings":Ratings_AS,
        "Total_Duration":Total_Duration_AS,
        "Prices":Prices_AS,
        "Seats_Available":Seats_Available_AS,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_5=pd.DataFrame(data_AS)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_5.csv"
df_buses_5.to_csv(path,index=False)

# %%
df_buses_5
# Out:
# Empty DataFrame
# Columns: [Bus_names, Bus_types, Start_Time, End_Time, Ratings, Total_Duration, Prices, Seats_Available, Route_names, Route_link]
# Index: []

# %% [markdown]
# RAJASTAN

# %%
#read the csv file
df_R=pd.read_csv("C:/Users/HP/Desktop/csv files/df_R.csv")
df_R
# Out:
#                                       route_name  \
# 0                             Udaipur to Jodhpur
# 1                               Jodhpur to Ajmer
# 2       Beawar (Rajasthan) to Jaipur (Rajasthan)
# 3                    Sikar to Jaipur (Rajasthan)
# 4                  Jaipur (Rajasthan) to Jodhpur
# 5  Aligarh (uttar pradesh) to Jaipur (Rajasthan)
# 6  Jaipur (Rajasthan) to Aligarh (uttar pradesh)
# 7                  Jodhpur to Beawar (Rajasthan)
# 8                   Jaipur (Rajasthan) to Pilani
# 9               Kishangarh to Jaipur (Rajasthan)
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/udaipur-to-j...
# 1  https://www.redbus.in/bus-tickets/jodhpur-to-a...
# 2  https://www.redbus.in/bus-tickets/beawer-to-ja...
# 3  https://www.redbus.in/bus-tickets/sikar-to-jaipur
# 4  https://www.redbus.in/bus-tickets/jaipur-to-jo...
# 5  https://www.redbus.in/bus-tickets/aligarh-utta...
# ...

# %%
#retreive the data
driver_R=webdriver.Chrome()
Bus_names_R=[]
Bus_types_R=[]
Start_Time_R=[]
End_Time_R=[]
Ratings_R=[]
Total_Duration_R=[]
Prices_R=[]
Seats_Available_R=[]
Route_names=[]
Route_links=[]

for i,r in df_R.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_R.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_R.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_R.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_R.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_R).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_R.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_R.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_R.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_R.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_R.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_R.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_R.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_R.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_R.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_R.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_R.append(bus_type.text)
  for start in start_time:
    Start_Time_R.append(start.text)
  for end in end_time:
    End_Time_R.append(end.text)
  for total in total_duration:
    Total_Duration_R.append(total.text)
  for rate in ratings:
    Ratings_R.append(rate.text)
  for pri in price:
    Prices_R.append(pri.text)
  for seats in seats_available:
    Seats_Available_R.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_R={"Bus_names":Bus_names_R,
        "Bus_types":Bus_types_R,
        "Start_Time":Start_Time_R,
        "End_Time":End_Time_R,
        "Ratings":Ratings_R,
        "Total_Duration":Total_Duration_R,
        "Prices":Prices_R,
        "Seats_Available":Seats_Available_R,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_6=pd.DataFrame(data_R)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_6.csv"
df_buses_6.to_csv(path,index=False)

# %%
df_buses_6
# Out:
#          Bus_names                      Bus_types Start_Time End_Time Ratings  \
# 0   RSRTC - 168781      Express Non AC Seater 2+3      14:15    16:30     3.9
# 1   RSRTC - 188889      Express Non AC Seater 2+3      14:15    16:15     3.9
# 2   RSRTC - 169343      Express Non AC Seater 2+3      14:30    16:45     3.9
# 3   RSRTC - 185839  Semi Deluxe Non AC Seater 2+2      14:35    16:50     3.9
# 4   RSRTC - 178605      Express Non AC Seater 2+3      14:40    17:00     3.9
# ..             ...                            ...        ...      ...     ...
# 65
# 66
# 67
# 68
# 69
#
#    Total_Duration   Prices     Seats_Available  \
# 0         02h 15m  INR 129  42 Seats available
# 1         02h 00m  INR 129  42 Seats available
# 2         02h 15m  INR 129  42 Seats available
# 3         02h 15m  INR 142  35 Seats available
# 4         02h 20m  INR 129  42 Seats available
# ..            ...      ...                 ...
# 65
# 66
# 67
# 68
# 69
#
# ...

# %% [markdown]
# SOUTH BENGAL

# %%
#read the csv file
df_SB=pd.read_csv("C:/Users/HP/Desktop/csv files/df_SB.csv")
df_SB
# Out:
#                           route_name  \
# 0               Durgapur to Calcutta
# 1                 Kolkata to Burdwan
# 2                 Haldia to Calcutta
# 3                  Kolkata to Haldia
# 4  Kolkata to Durgapur (West Bengal)
# 5  Kolkata to Arambagh (West Bengal)
# 6               Midnapore to Kolkata
# 7                   Kolkata to Digha
# 8                  Digha to Calcutta
# 9                 Kolkata to Bankura
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/durgapur-to-...
# 1  https://www.redbus.in/bus-tickets/kolkata-to-b...
# 2  https://www.redbus.in/bus-tickets/haldia-to-ko...
# 3  https://www.redbus.in/bus-tickets/kolkata-to-h...
# 4  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 5  https://www.redbus.in/bus-tickets/kolkata-to-a...
# 6  https://www.redbus.in/bus-tickets/midnapore-to...
# 7  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 8  https://www.redbus.in/bus-tickets/digha-to-kol...
# ...

# %%
#retreive the data
driver_SB=webdriver.Chrome()
Bus_names_SB=[]
Bus_types_SB=[]
Start_Time_SB=[]
End_Time_SB=[]
Ratings_SB=[]
Total_Duration_SB=[]
Prices_SB=[]
Seats_Available_SB=[]
Route_names=[]
Route_links=[]

for i,r in df_SB.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_SB.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_SB.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_SB.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_SB.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_SB).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_SB.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_SB.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_SB.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_SB.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_SB.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_SB.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_SB.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_SB.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_SB.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_SB.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_SB.append(bus_type.text)
  for start in start_time:
    Start_Time_SB.append(start.text)
  for end in end_time:
    End_Time_SB.append(end.text)
  for total in total_duration:
    Total_Duration_SB.append(total.text)
  for rate in ratings:
    Ratings_SB.append(rate.text)
  for pri in price:
    Prices_SB.append(pri.text)
  for seats in seats_available:
    Seats_Available_SB.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_SB={"Bus_names":Bus_names_SB,
        "Bus_types":Bus_types_SB,
        "Start_Time":Start_Time_SB,
        "End_Time":End_Time_SB,
        "Ratings":Ratings_SB,
        "Total_Duration":Total_Duration_SB,
        "Prices":Prices_SB,
        "Seats_Available":Seats_Available_SB,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_7=pd.DataFrame(data_SB)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_7.csv"
df_buses_7.to_csv(path,index=False)

# %%
df_buses_7
# Out:
#                                             Bus_names  \
# 0   SBSTC-HALDIA - KOLKATA - 14:00 (Haldia Depot) ...
# 1   SBSTC-HALDIA - KOLKATA - 15:00 (Haldia Depot) ...
# 2   SBSTC-HALDIA - KOLKATA - 16:05 (HALDIA DEPOT) ...
# 3   SBSTC-HALDIA - KOLKATA - ALL STOP - 17:30 (HLD...
# 4       WBTC (CTC) Habra- Barasat- Haldia - 180|16:45
# 5   SBSTC-KOLKATA - HALDIA - SPL - 14:05 (Haldia D...
# 6   SBSTC-KOLKATA - HALDIA - A/C - 14:30 (Haldia D...
# 7   SBSTC-KOLKATA - HALDIA - NON STOP - 15:30 (HAL...
# 8   SBSTC-KOLKATA - HALDIA - A/C - 16:05 (Haldia D...
# 9
# 10
# 11
# 12
# 13
# 14
# 15  SBSTC-HALDIA - ASANSOL - VIA - KOLKATA - 09:30...
# 16  SBSTC-KOLKATA - DURGAPUR - 14:00 (DGP DEPOT) -...
# 17  SBSTC-KARUNAMOYEE - ASANSOL - 14:00 (ASN DEPOT...
# 18
# 19
# 20
# 21
# 22
# 23
# 24
# 25  SBSTC-MIDNAPUR - HABRA - 14:00 (MID DEPOT) - 1397
# 26  SBSTC-MIDNAPUR - KOLKATA - 14:30 (MID DEPOT) -...
# 27  SBSTC-JHARGRAM - KARUNAMOYEE - VIA - KOLKATA -...
# ...

# %% [markdown]
# TELANGANA

# %%
#read the csv file
df_T=pd.read_csv("C:/Users/HP/Desktop/csv files/df_T.csv")
df_T
# Out:
#                 route_name                                         route_link
# 0  Hyderabad to Vijayawada  https://www.redbus.in/bus-tickets/hyderabad-to...
# 1     Khammam to Hyderabad  https://www.redbus.in/bus-tickets/khammam-to-h...
# 2     Hyderabad to Khammam  https://www.redbus.in/bus-tickets/hyderabad-to...
# 3   Hyderabad to Srisailam  https://www.redbus.in/bus-tickets/hyderabad-to...
# 4  Karimnagar to Hyderabad  https://www.redbus.in/bus-tickets/karimnagar-t...
# 5  Hyderabad to Karimnagar  https://www.redbus.in/bus-tickets/hyderabad-to...
# 6  Hyderabad to Mancherial  https://www.redbus.in/bus-tickets/hyderabad-to...
# 7      Hyderabad to Nirmal  https://www.redbus.in/bus-tickets/hyderabad-to...
# 8    Hyderabad to Adilabad  https://www.redbus.in/bus-tickets/hyderabad-to...
# 9      Hyderabad to Ongole  https://www.redbus.in/bus-tickets/hyderabad-to...

# %%
#retreive the data
driver_T=webdriver.Chrome()
Bus_names_T=[]
Bus_types_T=[]
Start_Time_T=[]
End_Time_T=[]
Ratings_T=[]
Total_Duration_T=[]
Prices_T=[]
Seats_Available_T=[]
Route_names=[]
Route_links=[]

for i,r in df_T.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_T.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_T.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_T.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_T.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_T).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_T.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_T.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_T.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_T.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_T.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_T.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_T.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_T.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_T.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_T.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_T.append(bus_type.text)
  for start in start_time:
    Start_Time_T.append(start.text)
  for end in end_time:
    End_Time_T.append(end.text)
  for total in total_duration:
    Total_Duration_T.append(total.text)
  for rate in ratings:
    Ratings_T.append(rate.text)
  for pri in price:
    Prices_T.append(pri.text)
  for seats in seats_available:
    Seats_Available_T.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_T={"Bus_names":Bus_names_T,
        "Bus_types":Bus_types_T,
        "Start_Time":Start_Time_T,
        "End_Time":End_Time_T,
        "Ratings":Ratings_T,
        "Total_Duration":Total_Duration_T,
        "Prices":Prices_T,
        "Seats_Available":Seats_Available_T,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_8=pd.DataFrame(data_T)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_8.csv"
df_buses_8.to_csv(path,index=False)

# %%
df_buses_8
# Out:
#                      Bus_names                                   Bus_types  \
# 0                 TSRTC - 8632              Rajdhani (AC Semi Sleeper 2+2)
# 1                 TSRTC - 8660                RAJDHANI (A.C. Semi Sleeper)
# 2                 TSRTC - 8850  Super Luxury (Non AC Seater 2+2 Push Back)
# 3                TSRTC - 64526  Super Luxury (Non AC Seater 2+2 Push Back)
# 4                 TSRTC - 6946  Super Luxury (Non AC Seater 2+2 Push Back)
# 5       Siri Tours and Travels                  A/C Seater / Sleeper (2+1)
# 6          Sri Krishna Travels              Non A/C Seater / Sleeper (2+1)
# 7       Sri Sai Balaji Travels                           A/C Sleeper (2+1)
# 8                  DMR Travels                           A/C Sleeper (2+1)
# 9         Gupta Travels Galaxy                  A/C Seater / Sleeper (2+2)
# 10                TSRTC - 7027  Super Luxury (Non AC Seater 2+2 Push Back)
# ...

# %% [markdown]
# UTTAR PRADESH

# %%
#read the csv file
df_UP=pd.read_csv("C:/Users/HP/Desktop/csv files/df_UP.csv")
df_UP
# Out:
#                              route_name  \
# 0                     Delhi to Bareilly
# 1                     Bareilly to Delhi
# 2      Aligarh (uttar pradesh) to Delhi
# 3      Delhi to Aligarh (uttar pradesh)
# 4                  Lucknow to Allahabad
# 5                      Lucknow to Delhi
# 6  Delhi to Farrukhabad (Uttar Pradesh)
# 7  Farrukhabad (Uttar Pradesh) to Delhi
# 8                       Badaun to Delhi
# 9                  Allahabad to Lucknow
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/delhi-to-bar...
# 1  https://www.redbus.in/bus-tickets/bareilly-to-...
# 2  https://www.redbus.in/bus-tickets/aligarh-utta...
# 3  https://www.redbus.in/bus-tickets/delhi-to-ali...
# 4  https://www.redbus.in/bus-tickets/lucknow-to-a...
# 5  https://www.redbus.in/bus-tickets/lucknow-to-d...
# 6  https://www.redbus.in/bus-tickets/delhi-to-far...
# 7  https://www.redbus.in/bus-tickets/farrukhabad-...
# ...

# %%
#retreive the data
driver_T=webdriver.Chrome()
Bus_names_T=[]
Bus_types_T=[]
Start_Time_T=[]
End_Time_T=[]
Ratings_T=[]
Total_Duration_T=[]
Prices_T=[]
Seats_Available_T=[]
Route_names=[]
Route_links=[]

for i,r in df_T.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_T.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_T.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_T.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_T.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_T).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_T.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_T.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_T.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_T.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_T.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_T.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_T.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_T.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_T.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_T.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_T.append(bus_type.text)
  for start in start_time:
    Start_Time_T.append(start.text)
  for end in end_time:
    End_Time_T.append(end.text)
  for total in total_duration:
    Total_Duration_T.append(total.text)
  for rate in ratings:
    Ratings_T.append(rate.text)
  for pri in price:
    Prices_T.append(pri.text)
  for seats in seats_available:
    Seats_Available_T.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_T={"Bus_names":Bus_names_T,
        "Bus_types":Bus_types_T,
        "Start_Time":Start_Time_T,
        "End_Time":End_Time_T,
        "Ratings":Ratings_T,
        "Total_Duration":Total_Duration_T,
        "Prices":Prices_T,
        "Seats_Available":Seats_Available_T,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_9=pd.DataFrame(data_T)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_9.csv"
df_buses_9.to_csv(path,index=False)

# %%
df_buses_9
# Out:
#                      Bus_names                                   Bus_types  \
# 0                 TSRTC - 7831                RAJDHANI (A.C. Semi Sleeper)
# 1                 TSRTC - 7067  Super Luxury (Non AC Seater 2+2 Push Back)
# 2                 TSRTC - 7304  Super Luxury (Non AC Seater 2+2 Push Back)
# 3
# 4
# 5
# 6
# 7
# 8
# 9                 TSRTC - 7092  Super Luxury (Non AC Seater 2+2 Push Back)
# 10                TSRTC - 7267  Super Luxury (Non AC Seater 2+2 Push Back)
# 11                TSRTC - 7279  Super Luxury (Non AC Seater 2+2 Push Back)
# 12
# 13
# 14
# 15
# 16
# 17                TSRTC - 8045           Lahari Non A/C Sleeper Cum Seater
# 18                TSRTC - 8059  Super Luxury (Non AC Seater 2+2 Push Back)
# 19                TSRTC - 8090  Super Luxury (Non AC Seater 2+2 Push Back)
# 20
# 21
# 22
# 23  New Royal Travels (Raipur)                  A/C Seater / Sleeper (2+1)
# 24  New Royal Travels (Raipur)                           A/C Sleeper (2+1)
# ...

# %% [markdown]
# WEST BENGAL

# %%
#read the csv file
df_WB=pd.read_csv("C:/Users/HP/Desktop/csv files/df_WB.csv")
df_WB
# Out:
#                                  route_name  \
# 0            Digha to Barasat (West Bengal)
# 1                      Durgapur to Calcutta
# 2                         Digha to Calcutta
# 3                          Kolkata to Digha
# 4            Barasat (West Bengal) to Digha
# 5                           Kolkata to Suri
# 6        Barasat (West Bengal) to Midnapore
# 7                      Midnapore to Kolkata
# 8         Barasat (West Bengal) to Kolaghat
# 9  Barasat (West Bengal) to Contai (Kanthi)
#
#                                           route_link
# 0  https://www.redbus.in/bus-tickets/digha-to-bar...
# 1  https://www.redbus.in/bus-tickets/durgapur-to-...
# 2  https://www.redbus.in/bus-tickets/digha-to-kol...
# 3  https://www.redbus.in/bus-tickets/kolkata-to-d...
# 4  https://www.redbus.in/bus-tickets/barasat-west...
# 5  https://www.redbus.in/bus-tickets/kolkata-to-suri
# 6  https://www.redbus.in/bus-tickets/barasat-west...
# ...

# %%
#retreive the data
driver_WB=webdriver.Chrome()
Bus_names_WB=[]
Bus_types_WB=[]
Start_Time_WB=[]
End_Time_WB=[]
Ratings_WB=[]
Total_Duration_WB=[]
Prices_WB=[]
Seats_Available_WB=[]
Route_names=[]
Route_links=[]

for i,r in df_WB.iterrows():
  link=r["route_link"]
  routes=r["route_name"]

#Loop through each Link

  driver_WB.get(link)
  time.sleep(2)

  #click on element to reveal the details
  elements=driver_WB.find_elements(By.XPATH, f"//a[contains(@href,'{link}')]")
  for element in elements:
    element.click()
    time.sleep(3)
  #click element to view bus
  try:
    clicks=driver_WB.find_element(By.XPATH,"//div[@class='button']")
    clicks.click()
  except:
    continue
  time.sleep(2)

  scrolling=True
  while scrolling:
    old_page_source=driver_WB.page_source

     #use Actionchains to perform a PAGE_DOWN
    ActionChains(driver_WB).send_keys(Keys.PAGE_DOWN).perform()
  
    time.sleep(5)
    new_page_source=driver_WB.page_source
  
    if new_page_source==old_page_source:
     scrolling=False

  bus_names=driver_WB.find_elements(By.XPATH, "//div[@class='travels lh-24 f-bold d-color']")
  bus_types=driver_WB.find_elements(By.XPATH, "//div[@class='bus-type f-12 m-top-16 l-color evBus']")
  start_time=driver_WB.find_elements(By.XPATH,"//*[@class='dp-time f-19 d-color f-bold']")
  end_time=driver_WB.find_elements(By.XPATH, "//*[@class='bp-time f-19 d-color disp-Inline']")
  total_duration=driver_WB.find_elements(By.XPATH, "//*[@class='dur l-color lh-24']")
  try:
    ratings=driver_WB.find_elements(By.XPATH,"//*[@class='column-six p-right-10 w-10 fl']" )
  except:
    continue
  price=driver_WB.find_elements(By.XPATH, "//div[@class='fare d-block']")
  seats_available=driver_WB.find_elements(By.XPATH, "//div[contains(@class,'seat-left')]")
  
  for name in bus_names:
    Bus_names_WB.append(name.text)
    Route_links.append(link)
    Route_names.append(routes)
  for bus_type in bus_types:
    Bus_types_WB.append(bus_type.text)
  for start in start_time:
    Start_Time_WB.append(start.text)
  for end in end_time:
    End_Time_WB.append(end.text)
  for total in total_duration:
    Total_Duration_WB.append(total.text)
  for rate in ratings:
    Ratings_WB.append(rate.text)
  for pri in price:
    Prices_WB.append(pri.text)
  for seats in seats_available:
    Seats_Available_WB.append(seats.text)
print('successfully completed')
# Out:
# successfully completed

# %%
#From list to convert dataframe
data_WB={"Bus_names":Bus_names_WB,
        "Bus_types":Bus_types_WB,
        "Start_Time":Start_Time_WB,
        "End_Time":End_Time_WB,
        "Ratings":Ratings_WB,
        "Total_Duration":Total_Duration_WB,
        "Prices":Prices_WB,
        "Seats_Available":Seats_Available_WB,
        "Route_names":Route_names,
        "Route_link":Route_links
        }

df_buses_10=pd.DataFrame(data_WB)

#convert to csv
path=r"C:/Users/HP/Desktop/csv files/datails.csv/df_buses_10.csv"
df_buses_10.to_csv(path,index=False)

# %%
df_buses_10
# Out:
#                                             Bus_names            Bus_types  \
# 0     WBTC (CTC) Joka - Tollygunge - Digha - 99|14:30  Non AC Seater (2+3)
# 1         WBTC (CTC) HABRA-DIGHA via Bally - 26|14:50  Non AC Seater (2+3)
# 2            WBTC (CTC) Khidderpur - Digha - 97|15:00  Non AC Seater (2+3)
# 3     WBTC (CTC) Joka - Tollygunge - Digha - 99|15:30  Non AC Seater (2+3)
# 4   WBTC (CTC) MADHYAMGRAM - DIGHA via Belghoria -...  Non AC Seater (2+3)
# 5                                     Samanta Travels     A/C Seater (2+3)
# 6                              Sneha Gold Bus Service     A/C Seater (2+3)
# 7                       Snemita Parisheba(SNEHA GOLD)      AC Seater (2+3)
# 8                             City Express (Shinjini)      AC Seater (2+3)
# 9                         Snemita Paribahan(Shinjini)     A/C Seater (2+3)
# 10             WBTC (CTC) Kolkata - Digha - 124|14:40  Non AC Seater (2+3)
# ...
